# %% [markdown]
# ### Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Plot and SVM for Setosa vs Versicolor

# %%
from matplotlib.colors import ListedColormap
from sklearn import svm
#The first 100 observations correspond to setosa and versicolor
start = 0
end = 100
for startind in range(0,3):
    endind = startind + 1
    plt.figure(figsize=(12,12))
    plt.subplot(2, 1, 1)
    plt.scatter(iris.data[start:end, startind], iris.data[start:end, endind], c=iris.target[start:end])
    plt.xlabel(iris.feature_names[startind])
    plt.ylabel(iris.feature_names[endind])
    plt.title(iris.feature_names[startind] + ' vs ' + iris.feature_names[endind])

    svc = svm.SVC(kernel='linear', C=1)
    X = iris.data[start:end, startind:endind+1]
    y = iris.target[start:end]
    svc.fit(X, y)

    #Adapted from https://github.com/jakevdp/sklearn_scipy2013
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
    cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

    def plot_estimator(estimator, X, y):
        estimator.fit(X, y)
        x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
        y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
        xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                             np.linspace(y_min, y_max, 100))
        Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        plt.figure()
        plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

        # Plot also the training points
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
        plt.axis('tight')
        plt.axis('off')
        plt.tight_layout()

    plot_estimator(svc, X, y)

# %% [markdown]
# ### Plot and SVM for Versicolor vs Virginica

# %%
#The last 100 observations correspond to versicolor and virginica
start = 50
end = 150
for startind in range(0,3):
    endind = startind + 1
    plt.figure(figsize=(12,12))
    plt.subplot(2, 1, 1)
    plt.scatter(iris.data[start:end, startind], iris.data[start:end, endind], c=iris.target[start:end])
    plt.xlabel(iris.feature_names[startind])
    plt.ylabel(iris.feature_names[endind])
    plt.title(iris.feature_names[startind] + ' vs ' + iris.feature_names[endind])

    svc = svm.SVC(kernel='linear', C=1)
    X = iris.data[start:end, startind:endind+1]
    y = iris.target[start:end]
    svc.fit(X, y)

    #Adapted from https://github.com/jakevdp/sklearn_scipy2013
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
    cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

    def plot_estimator(estimator, X, y):
        estimator.fit(X, y)
        x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
        y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
        xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                             np.linspace(y_min, y_max, 100))
        Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        plt.figure()
        plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

        # Plot also the training points
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
        plt.axis('tight')
        plt.axis('off')
        plt.tight_layout()

    plot_estimator(svc, X, y)

# %% [markdown]
# ### Plot and SVM for Setosa vs Virginica

# %%
#The first 50 and last 50 observations correspond to setosa and virginica
start1 = 0
end1 = 50
start2 = 100
end2 = 150
for startind in range(0,3):
    endind = startind + 1
    plt.figure(figsize=(12,12))
    plt.subplot(2, 1, 1)
    plt.scatter(np.append(iris.data[start1:end1, startind],iris.data[start2:end2, startind]),
                np.append(iris.data[start1:end1, endind],iris.data[start2:end2, endind]),
                c=np.append(iris.target[start1:end1],iris.target[start2:end2]))
    plt.xlabel(iris.feature_names[startind])
    plt.ylabel(iris.feature_names[endind])
    plt.title(iris.feature_names[startind] + ' vs ' + iris.feature_names[endind])

    svc = svm.SVC(kernel='linear', C=1)
    X = np.append(iris.data[start1:end1, startind:endind+1],iris.data[start2:end2, startind:endind+1], axis=0)
    y = np.append(iris.target[start1:end1],iris.target[start2:end2])
    svc.fit(X, y)

    #Adapted from https://github.com/jakevdp/sklearn_scipy2013
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
    cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

    def plot_estimator(estimator, X, y):
        estimator.fit(X, y)
        x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
        y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
        xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                             np.linspace(y_min, y_max, 100))
        Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        plt.figure()
        plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

        # Plot also the training points
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
        plt.axis('tight')
        plt.axis('off')
        plt.tight_layout()

    plot_estimator(svc, X, y)

# %% [markdown]
# ### Plot and SVM for all flower types

# %%
# All 3 flower types
start = 0
end = 150
for startind in range(0,3):
    endind = startind + 1
    plt.figure(figsize=(12,12))
    plt.subplot(2, 1, 1)
    plt.scatter(iris.data[start:end, startind], iris.data[start:end, endind], c=iris.target[start:end])
    plt.xlabel(iris.feature_names[startind])
    plt.ylabel(iris.feature_names[endind])
    plt.title(iris.feature_names[startind] + ' vs ' + iris.feature_names[endind])

    svc = svm.SVC(kernel='rbf', C=1000000)
    X = iris.data[start:end, startind:endind+1]
    y = iris.target[start:end]
    svc.fit(X, y)

    #Adapted from https://github.com/jakevdp/sklearn_scipy2013
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
    cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

    def plot_estimator(estimator, X, y):
        estimator.fit(X, y)
        x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
        y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
        xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                             np.linspace(y_min, y_max, 100))
        Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        plt.figure()
        plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

        # Plot also the training points
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
        plt.axis('tight')
        plt.axis('off')
        plt.tight_layout()

    plot_estimator(svc, X, y)
